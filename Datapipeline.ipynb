# %%
import pandas as pd
import plotly.express as px

# %%
file_path = 'RawDataAviation.csv'

data = pd.read_csv(file_path, delimiter=';')
data
# Out:
#         ID Airports   Periods  CrossCountryFlights_1  LocalFlights_2  \
# 0        0  A045844  1997JJ00                 467579          206214
# 1        1  A045844  1998JJ00                 485852          201265
# 2        2  A045844  1999MM01                  36810           14868
# 3        3  A045844  1999MM02                  34356           11314
# 4        4  A045844  1999MM03                  41290           18152
# ...    ...      ...       ...                    ...             ...
# 2515  2515  A043593  2023MM05                   1100            4939
# 2516  2516  A043593  2023MM06                   1194            5484
# 2517  2517  A043593  2023KW02                   3324           15193
# 2518  2518  A043593  2023MM07                   1016            4229
# 2519  2519  A043593  2023MM08                   1045            5272
#
#       TotalFlights_3 Scheduled_4  NonScheduled_5  TotalArrivalsFlights_6  \
# 0             400118      364095           36023                  200040
# 1             425608      387560           38048                  212751
# 2              33145       31222            1923                   16565
# 3              30912       29015            1897                   15444
# 4              35591       33278            2313                   17802
# ...              ...         ...             ...                     ...
# 2515             126           0             126                      56
# 2516             126           0             126                      64
# 2517             313           0             313                     150
# 2518             126           0             126                      62
# 2519             157           0             157                      73
#
#      Scheduled_7  ...  SouthAfrica_93  America_94 NorthAmerica_95  \
# 0         182043  ...               .           .               .
# 1         193792  ...               .           .               .
# 2          15616  ...               .           .               .
# 3          14513  ...               .           .               .
# 4          16644  ...               .           .               .
# ...          ...  ...             ...         ...             ...
# 2515           0  ...               0           0               0
# 2516           0  ...               0           0               0
# 2517           0  ...               0           0               0
# 2518           0  ...               0           0               0
# 2519           0  ...               0           0               0
#
#       CentralAmerica_96  SouthAmerica_97   Asia_98  WestAsia_99  \
# 0                     .                .         .            .
# 1                     .                .         .            .
# 2                     .                .         .            .
# 3                     .                .         .            .
# 4                     .                .         .            .
# ...                 ...              ...       ...          ...
# 2515                  0                0         0            0
# 2516                  0                0         0            0
# 2517                  0                0         0            0
# 2518                  0                0         0            0
# 2519                  0                0         0            0
#
#       SouthEastAsia_100 NorthEastAsia_101  Oceania_102
# 0                     .                 .            .
# 1                     .                 .            .
# 2                     .                 .            .
# 3                     .                 .            .
# 4                     .                 .            .
# ...                 ...               ...          ...
# 2515                  0                 0            0
# 2516                  0                 0            0
# 2517                  0                 0            0
# 2518                  0                 0            0
# 2519                  0                 0            0
#
# [2520 rows x 105 columns]

# %%
data.loc[ data['Airports'] == 'A045844', 'Airports'] = 'TOTAL'
data.loc[ data['Airports'] == 'A043590', 'Airports'] = 'Schiphol'
data.loc[ data['Airports'] == 'A043596', 'Airports'] = 'Rotterdam The Hague'
data.loc[ data['Airports'] == 'A043591', 'Airports'] = 'Eindhoven'
data.loc[ data['Airports'] == 'A043595', 'Airports'] = 'Maastricht Aachen'
data.loc[ data['Airports'] == 'A043593', 'Airports'] = 'Groningen'

# %%
data.set_index('ID')
# Out:
#        Airports   Periods  CrossCountryFlights_1  LocalFlights_2  \
# ID
# 0         TOTAL  1997JJ00                 467579          206214
# 1         TOTAL  1998JJ00                 485852          201265
# 2         TOTAL  1999MM01                  36810           14868
# 3         TOTAL  1999MM02                  34356           11314
# 4         TOTAL  1999MM03                  41290           18152
# ...         ...       ...                    ...             ...
# 2515  Groningen  2023MM05                   1100            4939
# 2516  Groningen  2023MM06                   1194            5484
# 2517  Groningen  2023KW02                   3324           15193
# 2518  Groningen  2023MM07                   1016            4229
# 2519  Groningen  2023MM08                   1045            5272
#
#       TotalFlights_3 Scheduled_4  NonScheduled_5  TotalArrivalsFlights_6  \
# ID
# 0             400118      364095           36023                  200040
# 1             425608      387560           38048                  212751
# 2              33145       31222            1923                   16565
# 3              30912       29015            1897                   15444
# 4              35591       33278            2313                   17802
# ...              ...         ...             ...                     ...
# 2515             126           0             126                      56
# 2516             126           0             126                      64
# 2517             313           0             313                     150
# 2518             126           0             126                      62
# 2519             157           0             157                      73
#
#      Scheduled_7  NonScheduled_8  ...  SouthAfrica_93 America_94  \
# ID                                ...
# 0         182043           17997  ...               .          .
# 1         193792           18959  ...               .          .
# 2          15616             949  ...               .          .
# 3          14513             931  ...               .          .
# 4          16644            1158  ...               .          .
# ...          ...             ...  ...             ...        ...
# 2515           0              56  ...               0          0
# 2516           0              64  ...               0          0
# 2517           0             150  ...               0          0
# 2518           0              62  ...               0          0
# 2519           0              73  ...               0          0
#
#       NorthAmerica_95  CentralAmerica_96 SouthAmerica_97   Asia_98  \
# ID
# 0                   .                  .               .         .
# 1                   .                  .               .         .
# 2                   .                  .               .         .
# 3                   .                  .               .         .
# 4                   .                  .               .         .
# ...               ...                ...             ...       ...
# 2515                0                  0               0         0
# 2516                0                  0               0         0
# 2517                0                  0               0         0
# 2518                0                  0               0         0
# 2519                0                  0               0         0
#
#       WestAsia_99 SouthEastAsia_100  NorthEastAsia_101  Oceania_102
# ID
# 0               .                 .                  .            .
# 1               .                 .                  .            .
# 2               .                 .                  .            .
# 3               .                 .                  .            .
# 4               .                 .                  .            .
# ...           ...               ...                ...          ...
# 2515            0                 0                  0            0
# 2516            0                 0                  0            0
# 2517            0                 0                  0            0
# 2518            0                 0                  0            0
# 2519            0                 0                  0            0
#
# [2520 rows x 104 columns]

# %%
data.loc[data['Periods'] == '2019MM01']
# Out:
#         ID             Airports   Periods  CrossCountryFlights_1  \
# 342    342                TOTAL  2019MM01                  43492
# 762    762             Schiphol  2019MM01                  38009
# 1182  1182  Rotterdam The Hague  2019MM01                   1607
# 1602  1602            Eindhoven  2019MM01                   2694
# 2022  2022    Maastricht Aachen  2019MM01                    631
# 2442  2442            Groningen  2019MM01                    551
#
#       LocalFlights_2  TotalFlights_3 Scheduled_4  NonScheduled_5  \
# 342             3547           41285       40217            1068
# 762              515           37185       36490             695
# 1182            1408             938         789             149
# 1602               0            2579        2489              90
# 2022             178             413         346              67
# 2442            1446             170         103              67
#
#       TotalArrivalsFlights_6 Scheduled_7  ...  SouthAfrica_93  America_94  \
# 342                    20634       20102  ...               2         589
# 762                    18588       18241  ...               2         589
# 1182                     471         396  ...               0           0
# 1602                    1289        1242  ...               0           0
# 2022                     202         171  ...               0           0
# 2442                      84          52  ...               0           0
#
#      NorthAmerica_95  CentralAmerica_96  SouthAmerica_97   Asia_98  \
# 342              380                 50              159       444
# 762              380                 50              159       444
# 1182               0                  0                0         0
# 1602               0                  0                0         0
# 2022               0                  0                0         0
# 2442               0                  0                0         0
#
#       WestAsia_99  SouthEastAsia_100 NorthEastAsia_101  Oceania_102
# 342            95                 97               252            0
# 762            95                 97               252            0
# 1182            0                  0                 0            0
# 1602            0                  0                 0            0
# 2022            0                  0                 0            0
# 2442            0                  0                 0            0
#
# [6 rows x 105 columns]

# %%
data_2019 = data.loc[data['Periods'].str.contains('2019MM', case=False)]

# %%
data_2019
# Out:
#         ID   Airports   Periods  CrossCountryFlights_1  LocalFlights_2  \
# 342    342      TOTAL  2019MM01                  43492            3547
# 343    343      TOTAL  2019MM02                  41972            3564
# 344    344      TOTAL  2019MM03                  47712            3992
# 346    346      TOTAL  2019MM04                  51400            4990
# 347    347      TOTAL  2019MM05                  55561            4923
# ...    ...        ...       ...                    ...             ...
# 2451  2451  Groningen  2019MM08                    932            1832
# 2452  2452  Groningen  2019MM09                    989            2302
# 2454  2454  Groningen  2019MM10                   1147            2620
# 2455  2455  Groningen  2019MM11                    712            1547
# 2456  2456  Groningen  2019MM12                    641            1173
#
#       TotalFlights_3 Scheduled_4  NonScheduled_5  TotalArrivalsFlights_6  \
# 342            41285       40217            1068                   20634
# 343            39204       38408             796                   19595
# 344            44649       43828             821                   22326
# 346            47934       46845            1089                   23965
# 347            51719       50253            1466                   25851
# ...              ...         ...             ...                     ...
# 2451             260         116             144                     132
# 2452             409         261             148                     203
# 2454             376         262             114                     187
# 2455             280         244              36                     139
# 2456             219         178              41                     111
#
#      Scheduled_7  ...  SouthAfrica_93  America_94 NorthAmerica_95  \
# 342        20102  ...               2         589             380
# 343        19196  ...               4         527             339
# 344        21915  ...               5         494             293
# 346        23363  ...               5         490             301
# 347        25132  ...               6         476             284
# ...          ...  ...             ...         ...             ...
# 2451          58  ...               0           0               0
# 2452         130  ...               0           0               0
# 2454         131  ...               0           0               0
# 2455         122  ...               0           0               0
# 2456          89  ...               0           0               0
#
#       CentralAmerica_96  SouthAmerica_97   Asia_98  WestAsia_99  \
# 342                  50              159       444           95
# 343                  45              143       395           93
# 344                  49              152       628           98
# 346                  50              139       579           88
# 347                  53              139       691           94
# ...                 ...              ...       ...          ...
# 2451                  0                0         0            0
# 2452                  0                0         0            0
# 2454                  0                0         0            0
# 2455                  0                0         0            0
# 2456                  0                0         0            0
#
#       SouthEastAsia_100 NorthEastAsia_101  Oceania_102
# 342                  97               252            0
# 343                  70               231            0
# 344                 134               397            0
# 346                 106               385            0
# 347                 174               423            0
# ...                 ...               ...          ...
# 2451                  0                 0            0
# 2452                  0                 0            0
# 2454                  0                 0            0
# 2455                  0                 0            0
# 2456                  0                 0            0
#
# [72 rows x 105 columns]

# %%
data_2019 = px.data.gapminder()
fig = px.line(data_2019, x = 'Periods', y = 'TotalFlights_3', color = 'Airports')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 2
#       1 data_2019 = px.data.gapminder()
# ----> 2 fig = px.line(data_2019, x = 'Periods', y = 'TotalFlights_3', color = 'Airports')
#       3 fig.show()
#
# File ~\anaconda3\envs\TIL6022\Lib\site-packages\plotly\express\_chart_types.py:264, in line(data_frame, x, y, line_group, color, line_dash, symbol, hover_name, hover_data, custom_data, text, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, error_x, error_x_minus, error_y, error_y_minus, animation_frame, animation_group, category_orders, labels, orientation, color_discrete_sequence, color_discrete_map, line_dash_sequence, line_dash_map, symbol_sequence, symbol_map, markers, log_x, log_y, range_x, range_y, line_shape, render_mode, title, template, width, height)
#     216 def line(
#     217     data_frame=None,
#     218     x=None,
#    (...)
#     258     height=None,
#     259 ) -> go.Figure:
#     260     """
#     261     In a 2D line plot, each row of `data_frame` is represented as vertex of
#     262     a polyline mark in 2D space.
#     263     """
# --> 264     return make_figure(args=locals(), constructor=go.Scatter)
#
# File ~\anaconda3\envs\TIL6022\Lib\site-packages\plotly\express\_core.py:1990, in make_figure(args, constructor, trace_patch, layout_patch)
#    1987 layout_patch = layout_patch or {}
#    1988 apply_default_cascade(args)
# -> 1990 args = build_dataframe(args, constructor)
#    1991 if constructor in [go.Treemap, go.Sunburst, go.Icicle] and args["path"] is not None:
#    1992     args = process_dataframe_hierarchy(args)
#
# File ~\anaconda3\envs\TIL6022\Lib\site-packages\plotly\express\_core.py:1405, in build_dataframe(args, constructor)
#    1402     args["color"] = None
#    1403 # now that things have been prepped, we do the systematic rewriting of `args`
# -> 1405 df_output, wide_id_vars = process_args_into_dataframe(
#    1406     args, wide_mode, var_name, value_name
#    1407 )
#    1409 # now that `df_output` exists and `args` contains only references, we complete
#    1410 # the special-case and wide-mode handling by further rewriting args and/or mutating
#    1411 # df_output
#    1413 count_name = _escape_col_name(df_output, "count", [var_name, value_name])
#
# File ~\anaconda3\envs\TIL6022\Lib\site-packages\plotly\express\_core.py:1207, in process_args_into_dataframe(args, wide_mode, var_name, value_name)
#    1205         if argument == "index":
#    1206             err_msg += "\n To use the index, pass it in directly as `df.index`."
# -> 1207         raise ValueError(err_msg)
#    1208 elif length and len(df_input[argument]) != length:
#    1209     raise ValueError(
#    1210         "All arguments should have the same length. "
#    1211         "The length of column argument `df[%s]` is %d, whereas the "
#    (...)
#    1218         )
#    1219     )
#
# ValueError: Value of 'x' is not the name of a column in 'data_frame'. Expected one of ['country', 'continent', 'year', 'lifeExp', 'pop', 'gdpPercap', 'iso_alpha', 'iso_num'] but received: Periods
